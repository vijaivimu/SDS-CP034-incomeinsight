# %%
import kagglehub
import pandas as pd
import os
from IPython.display import display

# Download latest version
path = kagglehub.dataset_download("uciml/adult-census-income")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/olaoluwatunmise/.cache/kagglehub/datasets/uciml/adult-census-income/versions/3

# %%
# Use the path from the previous cell
dataset_path = os.path.join(path, "adult.csv")
df = pd.read_csv(dataset_path)

# Display basic information about the dataset
print("Dataset shape:", df.shape)
print("\nFirst few rows:")
print(df.head())
print("\nDataset info:")
print(df.info())
print("\nColumn names:")
print(df.columns.tolist())
# Out:
# Dataset shape: (32561, 15)
#
# First few rows:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#        occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0               ?  Not-in-family  White  Female             0          4356
# 1  Exec-manage...  Not-in-family  White  Female             0          4356
# 2               ?      Unmarried  Black  Female             0          4356
# 3  Machine-op-...      Unmarried  White  Female             0          3900
# 4  Prof-specialty      Own-child  White  Female             0          3900
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K
# 3              40  United-States  <=50K
# 4              40  United-States  <=50K
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None
#
# Column names:
# ['age', 'workclass', 'fnlwgt', 'education', 'education.num', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'capital.gain', 'capital.loss', 'hours.per.week', 'native.country', 'income']

# %%
# Set pandas display options for better formatting


# Set display options to show more columns and prevent line wrapping
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)        # Don't wrap to new lines
pd.set_option('display.max_colwidth', 15)   # Limit column width for readability

# # Display the first few rows in a more compact format
print("First few rows (compact display):")
print(df.head())

# Alternative: Use display() function for even better formatting in Jupyter
from IPython.display import display
print("\nUsing display() function:")
display(df.head())
# Out:
# First few rows (compact display):
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#        occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0               ?  Not-in-family  White  Female             0          4356
# 1  Exec-manage...  Not-in-family  White  Female             0          4356
# 2               ?      Unmarried  Black  Female             0          4356
# 3  Machine-op-...      Unmarried  White  Female             0          3900
# 4  Prof-specialty      Own-child  White  Female             0          3900
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K
# 3              40  United-States  <=50K
# 4              40  United-States  <=50K
#
# Using display() function:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#        occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0               ?  Not-in-family  White  Female             0          4356
# 1  Exec-manage...  Not-in-family  White  Female             0          4356
# 2               ?      Unmarried  Black  Female             0          4356
# 3  Machine-op-...      Unmarried  White  Female             0          3900
# 4  Prof-specialty      Own-child  White  Female             0          3900
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K
# 3              40  United-States  <=50K
# 4              40  United-States  <=50K

# %% [markdown]
# ### Cleaning column names

# %%
# Remove dots and replace with underscores, convert to lowercase
df.columns = df.columns.str.replace('.', '_').str.lower()

# Display the cleaned column names
print("Cleaned column names:")
print(df.columns.tolist())

# Display first few rows to confirm the changes
print("\nFirst few rows with cleaned column names:")
print(df.head())

# Show dataset info again
print("\nDataset info with cleaned columns:")
print(df.info())
# Out:
# Cleaned column names:
# ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']
#
# First few rows with cleaned column names:
#    age workclass  fnlwgt     education  education_num marital_status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#        occupation   relationship   race     sex  capital_gain  capital_loss  \
# 0               ?  Not-in-family  White  Female             0          4356
# 1  Exec-manage...  Not-in-family  White  Female             0          4356
# 2               ?      Unmarried  Black  Female             0          4356
# 3  Machine-op-...      Unmarried  White  Female             0          3900
# 4  Prof-specialty      Own-child  White  Female             0          3900
#
#    hours_per_week native_country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K
# 3              40  United-States  <=50K
# 4              40  United-States  <=50K
#
# Dataset info with cleaned columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %% [markdown]
# ### Handling missing values

# %%
import numpy as np 

# First, let's see how many missing values we have in each column
print("Missing values count before cleaning:")
print(df.isnull().sum())
# Out:
# Missing values count before cleaning:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Replace '?' with NaN
df = df.replace('?', np.nan)

# %%
print("\nMissing values count after replacing '?' with NaN:")
print(df.isnull().sum())
# Out:
# Missing values count after replacing '?' with NaN:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# income               0
# dtype: int64

# %%
# Display the data types to understand which columns are categorical vs numerical
print("\nData types:")
print(df.dtypes)
# Out:
# Data types:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
# Drop rows with missing values
print("Dataset shape before dropping missing values:", df.shape)
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Dataset shape before dropping missing values: (32561, 15)
# Total missing values: 4262

# %%
# Drop rows with any missing values
df_clean = df.dropna()

print("\nDataset shape after dropping missing values:", df_clean.shape)
print("Total missing values after cleaning:", df_clean.isnull().sum().sum())
# Out:
# Dataset shape after dropping missing values: (30162, 15)
# Total missing values after cleaning: 0

# %%
# Calculate percentage of data retained
percentage_retained = (len(df_clean) / len(df)) * 100
print(f"Percentage of data retained: {percentage_retained:.2f}%")
# Out:
# Percentage of data retained: 92.63%

# %%
# Display first few rows of cleaned dataset
print("\nFirst few rows of cleaned dataset:")
display(df_clean.head())
# Out:
# First few rows of cleaned dataset:
#    age workclass  fnlwgt     education  education_num marital_status  \
# 1   82   Private  132870       HS-grad              9        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
# 5   34   Private  216864       HS-grad              9       Divorced
# 6   38   Private  150601          10th              6      Separated
#
#        occupation   relationship   race     sex  capital_gain  capital_loss  \
# 1  Exec-manage...  Not-in-family  White  Female             0          4356
# 3  Machine-op-...      Unmarried  White  Female             0          3900
# 4  Prof-specialty      Own-child  White  Female             0          3900
# 5   Other-service      Unmarried  White  Female             0          3770
# 6    Adm-clerical      Unmarried  White    Male             0          3770
#
#    hours_per_week native_country income
# 1              18  United-States  <=50K
# 3              40  United-States  <=50K
# 4              40  United-States  <=50K
# 5              45  United-States  <=50K
# 6              40  United-States  <=50K

# %%
# Show summary statistics of cleaned dataset
print("\nSummary statistics of cleaned dataset:")
display(df_clean.describe())
# Out:
# Summary statistics of cleaned dataset:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  30162.000000  3.016200e+04   30162.000000  30162.000000  30162.000000
# mean      38.437902  1.897938e+05      10.121312   1092.007858     88.372489
# std       13.134665  1.056530e+05       2.549995   7406.346497    404.298370
# min       17.000000  1.376900e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.176272e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.784250e+05      10.000000      0.000000      0.000000
# 75%       47.000000  2.376285e+05      13.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    30162.000000
# mean        40.931238
# std         11.979984
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Verify no missing values remain
print("\nMissing values check:")
print(df_clean.isnull().sum())
# Out:
# Missing values check:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
# Your dataset categorical features
categorical_features = ['workclass', 'education', 'marital_status', 'occupation', 
                       'relationship', 'race', 'sex', 'native_country', 'income']

print("Cardinality Analysis:")
print("=" * 40)

for feature in categorical_features:
    unique_count = df_clean[feature].nunique()
    unique_values = df_clean[feature].unique()
    
    print(f"\n{feature}:")
    print(f"  Unique values: {unique_count}")
    print(f"  Values: {list(unique_values)}")
    
    if unique_count > 15:
        print("  → HIGH CARDINALITY (Use Label Encoding)")
    else:
        print("  → LOW CARDINALITY (Use One-Hot Encoding)")
# Out:
# Cardinality Analysis:
# ========================================
#
# workclass:
#   Unique values: 7
#   Values: ['Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc', 'Self-emp-inc', 'Local-gov', 'Without-pay']
#   → LOW CARDINALITY (Use One-Hot Encoding)
#
# education:
#   Unique values: 16
#   Values: ['HS-grad', '7th-8th', 'Some-college', '10th', 'Doctorate', 'Prof-school', 'Bachelors', 'Masters', '11th', 'Assoc-voc', '1st-4th', '5th-6th', 'Assoc-acdm', '12th', '9th', 'Preschool']
#   → HIGH CARDINALITY (Use Label Encoding)
#
# marital_status:
#   Unique values: 7
#   Values: ['Widowed', 'Divorced', 'Separated', 'Never-married', 'Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse']
#   → LOW CARDINALITY (Use One-Hot Encoding)
#
# occupation:
#   Unique values: 14
#   Values: ['Exec-managerial', 'Machine-op-inspct', 'Prof-specialty', 'Other-service', 'Adm-clerical', 'Transport-moving', 'Sales', 'Craft-repair', 'Farming-fishing', 'Tech-support', 'Protective-serv', 'Handlers-cleaners', 'Armed-Forces', 'Priv-house-serv']
#   → LOW CARDINALITY (Use One-Hot Encoding)
#
# relationship:
#   Unique values: 6
#   Values: ['Not-in-family', 'Unmarried', 'Own-child', 'Other-relative', 'Husband', 'Wife']
#   → LOW CARDINALITY (Use One-Hot Encoding)
#
# race:
#   Unique values: 5
#   Values: ['White', 'Black', 'Asian-Pac-Islander', 'Other', 'Amer-Indian-Eskimo']
#   → LOW CARDINALITY (Use One-Hot Encoding)
#
# sex:
#   Unique values: 2
#   Values: ['Female', 'Male']
#   → LOW CARDINALITY (Use One-Hot Encoding)
#
# native_country:
#   Unique values: 41
#   Values: ['United-States', 'Mexico', 'Greece', 'Vietnam', 'China', 'Taiwan', 'India', 'Philippines', 'Trinadad&Tobago', 'Canada', 'South', 'Holand-Netherlands', 'Puerto-Rico', 'Poland', 'Iran', 'England', 'Germany', 'Italy', 'Japan', 'Hong', 'Honduras', 'Cuba', 'Ireland', 'Cambodia', 'Peru', 'Nicaragua', 'Dominican-Republic', 'Haiti', 'Hungary', 'Columbia', 'Guatemala', 'El-Salvador', 'Jamaica', 'Ecuador', 'France', 'Yugoslavia', 'Portugal', 'Laos', 'Thailand', 'Outlying-US(Guam-USVI-etc)', 'Scotland']
#   → HIGH CARDINALITY (Use Label Encoding)
#
# income:
#   Unique values: 2
#   Values: ['<=50K', '>50K']
#   → LOW CARDINALITY (Use One-Hot Encoding)

# %%
# Encode categorical variables
from sklearn.preprocessing import LabelEncoder

# %%
# First, let's check the cardinality of each categorical variable
categorical_cols = ['workclass', 'education', 'marital_status', 'occupation', 
                   'relationship', 'race', 'sex', 'native_country', 'income']

print("Cardinality of categorical variables:")
for col in categorical_cols:
    unique_count = df_clean[col].nunique()
    print(f"{col}: {unique_count} unique values")


# Define high-cardinality and low-cardinality features
high_cardinality = ['occupation', 'native_country', 'education']  # >10 unique values
low_cardinality = ['workclass', 'marital_status', 'relationship', 'race', 'sex', 'income']  # ≤10 unique values

print(f"\nHigh-cardinality features (will use label encoding): {high_cardinality}")
print(f"Low-cardinality features (will use one-hot encoding): {low_cardinality}")
# Out:
# Cardinality of categorical variables:
# workclass: 7 unique values
# education: 16 unique values
# marital_status: 7 unique values
# occupation: 14 unique values
# relationship: 6 unique values
# race: 5 unique values
# sex: 2 unique values
# native_country: 41 unique values
# income: 2 unique values
#
# High-cardinality features (will use label encoding): ['occupation', 'native_country', 'education']
# Low-cardinality features (will use one-hot encoding): ['workclass', 'marital_status', 'relationship', 'race', 'sex', 'income']

# %%
# Create a copy of the cleaned dataset for encoding
df_encoded = df_clean.copy()

# 1. Label Encoding for high-cardinality features
label_encoders = {}
for col in high_cardinality:
    le = LabelEncoder()
    df_encoded[col + '_encoded'] = le.fit_transform(df_encoded[col])
    label_encoders[col] = le
    print(f"Label encoded {col}: {len(le.classes_)} classes")
# Out:
# Label encoded occupation: 14 classes
# Label encoded native_country: 41 classes
# Label encoded education: 16 classes

# %%
# 2. One-hot encoding for low-cardinality features
df_encoded = pd.get_dummies(df_encoded, columns=low_cardinality, prefix=low_cardinality)

# Display the encoded dataset info
print(f"\nDataset shape after encoding: {df_encoded.shape}")
print(f"Number of features after encoding: {df_encoded.shape[1]}")

# Show the new column names
print("\nNew column names after encoding:")
print(df_encoded.columns.tolist())

# Display first few rows of encoded dataset
print("\nFirst few rows of encoded dataset:")
display(df_encoded.head())
# Out:
# Dataset shape after encoding: (30162, 41)
# Number of features after encoding: 41
#
# New column names after encoding:
# ['age', 'fnlwgt', 'education', 'education_num', 'occupation', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'occupation_encoded', 'native_country_encoded', 'education_encoded', 'workclass_Federal-gov', 'workclass_Local-gov', 'workclass_Private', 'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc', 'workclass_State-gov', 'workclass_Without-pay', 'marital_status_Divorced', 'marital_status_Married-AF-spouse', 'marital_status_Married-civ-spouse', 'marital_status_Married-spouse-absent', 'marital_status_Never-married', 'marital_status_Separated', 'marital_status_Widowed', 'relationship_Husband', 'relationship_Not-in-family', 'relationship_Other-relative', 'relationship_Own-child', 'relationship_Unmarried', 'relationship_Wife', 'race_Amer-Indian-Eskimo', 'race_Asian-Pac-Islander', 'race_Black', 'race_Other', 'race_White', 'sex_Female', 'sex_Male', 'income_<=50K', 'income_>50K']
#
# First few rows of encoded dataset:
#    age  fnlwgt     education  education_num      occupation  capital_gain  \
# 1   82  132870       HS-grad              9  Exec-manage...             0
# 3   54  140359       7th-8th              4  Machine-op-...             0
# 4   41  264663  Some-college             10  Prof-specialty             0
# 5   34  216864       HS-grad              9   Other-service             0
# 6   38  150601          10th              6    Adm-clerical             0
#
#    capital_loss  hours_per_week native_country  occupation_encoded  \
# 1          4356              18  United-States               3
# 3          3900              40  United-States               6
# 4          3900              40  United-States               9
# 5          3770              45  United-States               7
# 6          3770              40  United-States               0
#
#    native_country_encoded  education_encoded  workclass_Federal-gov  \
# 1              38                      11              False
# 3              38                       5              False
# 4              38                      15              False
# 5              38                      11              False
# 6              38                       0              False
#
#    workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# 1           False                 True              False
# 3           False                 True              False
# 4           False                 True              False
# 5           False                 True              False
# 6           False                 True              False
#
#    workclass_Self-emp-not-inc  workclass_State-gov  workclass_Without-pay  \
# 1           False                       False                False
# 3           False                       False                False
# 4           False                       False                False
# 5           False                       False                False
# 6           False                       False                False
#
#    marital_status_Divorced  marital_status_Married-AF-spouse  \
# 1           False                    False
# 3            True                    False
# 4           False                    False
# 5            True                    False
# 6           False                    False
#
#    marital_status_Married-civ-spouse  marital_status_Married-spouse-absent  \
# 1           False                              False
# 3           False                              False
# 4           False                              False
# 5           False                              False
# 6           False                              False
#
#    marital_status_Never-married  marital_status_Separated  \
# 1           False                         False
# 3           False                         False
# 4           False                          True
# 5           False                         False
# 6           False                          True
#
#    marital_status_Widowed  relationship_Husband  relationship_Not-in-family  \
# 1            True                   False                  True
# 3           False                   False                 False
# 4           False                   False                 False
# 5           False                   False                 False
# 6           False                   False                 False
#
#    relationship_Other-relative  relationship_Own-child  \
# 1           False                        False
# 3           False                        False
# 4           False                         True
# 5           False                        False
# 6           False                        False
#
#    relationship_Unmarried  relationship_Wife  race_Amer-Indian-Eskimo  \
# 1           False                   False              False
# 3            True                   False              False
# 4           False                   False              False
# 5            True                   False              False
# 6            True                   False              False
#
#    race_Asian-Pac-Islander  race_Black  race_Other  race_White  sex_Female  \
# 1           False                False       False        True        True
# 3           False                False       False        True        True
# 4           False                False       False        True        True
# 5           False                False       False        True        True
# 6           False                False       False        True       False
#
#    sex_Male  income_<=50K  income_>50K
# 1     False          True        False
# 3     False          True        False
# 4     False          True        False
# 5     False          True        False
# 6      True          True        False

# %%
# Show summary of the encoding
print("\nEncoding Summary:")
print("=" * 50)
print("Label Encoded Features:")
for col in high_cardinality:
    print(f"  {col}: {len(label_encoders[col].classes_)} classes")
    print(f"    Classes: {list(label_encoders[col].classes_)}")

print("\nOne-Hot Encoded Features:")
for col in low_cardinality:
    encoded_cols = [c for c in df_encoded.columns if c.startswith(col + '_')]
    print(f"  {col}: {len(encoded_cols)} dummy variables")
    print(f"    Dummy variables: {encoded_cols}")

# Show data types of encoded dataset
print("\nData types after encoding:")
print(df_encoded.dtypes.value_counts())
# Out:
# Encoding Summary:
# ==================================================
# Label Encoded Features:
#   occupation: 14 classes
#     Classes: ['Adm-clerical', 'Armed-Forces', 'Craft-repair', 'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners', 'Machine-op-inspct', 'Other-service', 'Priv-house-serv', 'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support', 'Transport-moving']
#   native_country: 41 classes
#     Classes: ['Cambodia', 'Canada', 'China', 'Columbia', 'Cuba', 'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England', 'France', 'Germany', 'Greece', 'Guatemala', 'Haiti', 'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India', 'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos', 'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Puerto-Rico', 'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago', 'United-States', 'Vietnam', 'Yugoslavia']
#   education: 16 classes
#     Classes: ['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th', '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate', 'HS-grad', 'Masters', 'Preschool', 'Prof-school', 'Some-college']
#
# One-Hot Encoded Features:
#   workclass: 7 dummy variables
#     Dummy variables: ['workclass_Federal-gov', 'workclass_Local-gov', 'workclass_Private', 'workclass_Self-emp-inc', 'workclass_Self-emp-not-inc', 'workclass_State-gov', 'workclass_Without-pay']
#   marital_status: 7 dummy variables
#     Dummy variables: ['marital_status_Divorced', 'marital_status_Married-AF-spouse', 'marital_status_Married-civ-spouse', 'marital_status_Married-spouse-absent', 'marital_status_Never-married', 'marital_status_Separated', 'marital_status_Widowed']
#   relationship: 6 dummy variables
#     Dummy variables: ['relationship_Husband', 'relationship_Not-in-family', 'relationship_Other-relative', 'relationship_Own-child', 'relationship_Unmarried', 'relationship_Wife']
#   race: 5 dummy variables
#     Dummy variables: ['race_Amer-Indian-Eskimo', 'race_Asian-Pac-Islander', 'race_Black', 'race_Other', 'race_White']
#   sex: 2 dummy variables
#     Dummy variables: ['sex_Female', 'sex_Male']
#   income: 2 dummy variables
#     Dummy variables: ['income_<=50K', 'income_>50K']
#
# Data types after encoding:
# bool      29
# int64      9
# object     3
# Name: count, dtype: int64

# %%
df_encoded
# Out:
#        age  fnlwgt     education  education_num      occupation  capital_gain  \
# 1       82  132870       HS-grad              9  Exec-manage...             0
# 3       54  140359       7th-8th              4  Machine-op-...             0
# 4       41  264663  Some-college             10  Prof-specialty             0
# 5       34  216864       HS-grad              9   Other-service             0
# 6       38  150601          10th              6    Adm-clerical             0
# ...    ...     ...           ...            ...             ...           ...
# 32556   22  310152  Some-college             10  Protective-...             0
# 32557   27  257302    Assoc-acdm             12    Tech-support             0
# 32558   40  154374       HS-grad              9  Machine-op-...             0
# 32559   58  151910       HS-grad              9    Adm-clerical             0
# 32560   22  201490       HS-grad              9    Adm-clerical             0
#
#        capital_loss  hours_per_week native_country  occupation_encoded  \
# 1              4356              18  United-States               3
# 3              3900              40  United-States               6
# 4              3900              40  United-States               9
# 5              3770              45  United-States               7
# 6              3770              40  United-States               0
# ...             ...             ...            ...             ...
# 32556             0              40  United-States              10
# 32557             0              38  United-States              12
# 32558             0              40  United-States               6
# 32559             0              40  United-States               0
# 32560             0              20  United-States               0
#
#        native_country_encoded  education_encoded  workclass_Federal-gov  \
# 1                  38                      11              False
# 3                  38                       5              False
# 4                  38                      15              False
# 5                  38                      11              False
# 6                  38                       0              False
# ...               ...                     ...                ...
# 32556              38                      15              False
# 32557              38                       7              False
# 32558              38                      11              False
# 32559              38                      11              False
# 32560              38                      11              False
#
#        workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# 1               False                 True              False
# 3               False                 True              False
# 4               False                 True              False
# 5               False                 True              False
# 6               False                 True              False
# ...               ...                  ...                ...
# 32556           False                 True              False
# 32557           False                 True              False
# 32558           False                 True              False
# 32559           False                 True              False
# 32560           False                 True              False
#
#        workclass_Self-emp-not-inc  workclass_State-gov  workclass_Without-pay  \
# 1               False                       False                False
# 3               False                       False                False
# 4               False                       False                False
# 5               False                       False                False
# 6               False                       False                False
# ...               ...                         ...                  ...
# 32556           False                       False                False
# 32557           False                       False                False
# 32558           False                       False                False
# 32559           False                       False                False
# 32560           False                       False                False
#
#        marital_status_Divorced  marital_status_Married-AF-spouse  \
# 1               False                    False
# 3                True                    False
# 4               False                    False
# 5                True                    False
# 6               False                    False
# ...               ...                      ...
# 32556           False                    False
# 32557           False                    False
# 32558           False                    False
# 32559           False                    False
# 32560           False                    False
#
#        marital_status_Married-civ-spouse  \
# 1               False
# 3               False
# 4               False
# 5               False
# 6               False
# ...               ...
# 32556           False
# 32557            True
# 32558            True
# 32559           False
# 32560           False
#
#        marital_status_Married-spouse-absent  marital_status_Never-married  \
# 1               False                                 False
# 3               False                                 False
# 4               False                                 False
# 5               False                                 False
# 6               False                                 False
# ...               ...                                   ...
# 32556           False                                  True
# 32557           False                                 False
# 32558           False                                 False
# 32559           False                                 False
# 32560           False                                  True
#
#        marital_status_Separated  marital_status_Widowed  relationship_Husband  \
# 1               False                      True                   False
# 3               False                     False                   False
# 4                True                     False                   False
# 5               False                     False                   False
# 6                True                     False                   False
# ...               ...                       ...                     ...
# 32556           False                     False                   False
# 32557           False                     False                   False
# 32558           False                     False                    True
# 32559           False                      True                   False
# 32560           False                     False                   False
#
#        relationship_Not-in-family  relationship_Other-relative  \
# 1                True                       False
# 3               False                       False
# 4               False                       False
# 5               False                       False
# 6               False                       False
# ...               ...                         ...
# 32556            True                       False
# 32557           False                       False
# 32558           False                       False
# 32559           False                       False
# 32560           False                       False
#
#        relationship_Own-child  relationship_Unmarried  relationship_Wife  \
# 1               False                   False                   False
# 3               False                    True                   False
# 4                True                   False                   False
# 5               False                    True                   False
# 6               False                    True                   False
# ...               ...                     ...                     ...
# 32556           False                   False                   False
# 32557           False                   False                    True
# 32558           False                   False                   False
# 32559           False                    True                   False
# 32560            True                   False                   False
#
#        race_Amer-Indian-Eskimo  race_Asian-Pac-Islander  race_Black  \
# 1               False                    False                False
# 3               False                    False                False
# 4               False                    False                False
# 5               False                    False                False
# 6               False                    False                False
# ...               ...                      ...                  ...
# 32556           False                    False                False
# 32557           False                    False                False
# 32558           False                    False                False
# 32559           False                    False                False
# 32560           False                    False                False
#
#        race_Other  race_White  sex_Female  sex_Male  income_<=50K  income_>50K
# 1           False        True        True     False          True        False
# 3           False        True        True     False          True        False
# 4           False        True        True     False          True        False
# 5           False        True        True     False          True        False
# 6           False        True       False      True          True        False
# ...           ...         ...         ...       ...           ...          ...
# 32556       False        True       False      True          True        False
# 32557       False        True        True     False          True        False
# 32558       False        True       False      True         False         True
# 32559       False        True        True     False          True        False
# 32560       False        True       False      True          True        False
#
# [30162 rows x 41 columns]
